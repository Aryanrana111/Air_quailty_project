# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\ar870\OneDrive\Documents\archive (32)\final_dataset.csv")
df
# Out:
#       Date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2    SO2  \
# 0        1      1  2021               0     5  408.80  442.42  160.61  12.95
# 1        2      1  2021               0     6  404.04  561.95   52.85   5.18
# 2        3      1  2021               1     7  225.07  239.04  170.95  10.93
# 3        4      1  2021               0     1   89.55  132.08  153.98  10.42
# 4        5      1  2021               0     2   54.06   55.54  122.66   9.70
# ...    ...    ...   ...             ...   ...     ...     ...     ...    ...
# 1456    27     12  2024               0     5   58.43  249.17   41.69  65.89
# 1457    28     12  2024               0     6   33.83  150.77   33.31  66.14
# 1458    29     12  2024               1     7   31.21  139.75   27.01  65.94
# 1459    30     12  2024               0     1   38.01  152.83   29.12  65.16
# 1460    31     12  2024               0     2   80.42  318.96   40.37  64.98
#
#         CO  Ozone  AQI
# 0     2.77  43.19  462
# 1     2.60  16.43  482
# 2     1.40  44.29  263
# 3     1.01  49.19  207
# 4     0.64  48.88  149
# ...    ...    ...  ...
# 1456  0.99  36.25  263
# 1457  0.79  35.19  113
# 1458  0.57  35.88  142
# 1459  0.55  38.38  116
# 1460  0.84  39.93  209
#
# [1461 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# Date              0
# Month             0
# Year              0
# Holidays_Count    0
# Days              0
# PM2.5             0
# PM10              0
# NO2               0
# SO2               0
# CO                0
# Ozone             0
# AQI               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            1461 non-null   int64
#  1   Month           1461 non-null   int64
#  2   Year            1461 non-null   int64
#  3   Holidays_Count  1461 non-null   int64
#  4   Days            1461 non-null   int64
#  5   PM2.5           1461 non-null   float64
#  6   PM10            1461 non-null   float64
#  7   NO2             1461 non-null   float64
#  8   SO2             1461 non-null   float64
#  9   CO              1461 non-null   float64
#  10  Ozone           1461 non-null   float64
#  11  AQI             1461 non-null   int64
# dtypes: float64(6), int64(6)
# memory usage: 137.1 KB

# %%
df["Days"] = df["Days"].astype(str)

# %%
di = {
    "1":"Monday",
    "2":"Tuseday",
    "3":"Wednesday",
    "4":"Thursday",
    "5":"Friday",
    "6":"Saturday",
    "7":"Sunday"
}

# %%
df["Days"].replace(di , inplace=True)
# Out:
# C:\Users\ar870\AppData\Local\Temp\ipykernel_3144\518233111.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Days"].replace(di , inplace=True)

# %%
df
# Out:
#       Date  Month  Year  Holidays_Count      Days   PM2.5    PM10     NO2  \
# 0        1      1  2021               0    Friday  408.80  442.42  160.61
# 1        2      1  2021               0  Saturday  404.04  561.95   52.85
# 2        3      1  2021               1    Sunday  225.07  239.04  170.95
# 3        4      1  2021               0    Monday   89.55  132.08  153.98
# 4        5      1  2021               0   Tuseday   54.06   55.54  122.66
# ...    ...    ...   ...             ...       ...     ...     ...     ...
# 1456    27     12  2024               0    Friday   58.43  249.17   41.69
# 1457    28     12  2024               0  Saturday   33.83  150.77   33.31
# 1458    29     12  2024               1    Sunday   31.21  139.75   27.01
# 1459    30     12  2024               0    Monday   38.01  152.83   29.12
# 1460    31     12  2024               0   Tuseday   80.42  318.96   40.37
#
#         SO2    CO  Ozone  AQI
# 0     12.95  2.77  43.19  462
# 1      5.18  2.60  16.43  482
# 2     10.93  1.40  44.29  263
# 3     10.42  1.01  49.19  207
# 4      9.70  0.64  48.88  149
# ...     ...   ...    ...  ...
# 1456  65.89  0.99  36.25  263
# 1457  66.14  0.79  35.19  113
# 1458  65.94  0.57  35.88  142
# 1459  65.16  0.55  38.38  116
# 1460  64.98  0.84  39.93  209
#
# [1461 rows x 12 columns]

# %%
di = {
    1 : "January",
    2: "Febuary",
    3:"March",
    4:"April",
    5:"May",
    6:"June",
    7:"July",
    8:"Augest",
    9:"September",
    10:"October",
    11:"November",
    12:"December"
}

# %%
df["Month"].replace(di , inplace = True)
# Out:
# C:\Users\ar870\AppData\Local\Temp\ipykernel_3144\1875630362.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Month"].replace(di , inplace = True)

# %% [markdown]
# What is the average AQI per month?

# %%
group = df.groupby("Month")["AQI"].mean()
group = group.sort_values(ascending = False)

# %%
group.plot(kind="bar")
# Out:
# <Axes: xlabel='Month'>

# %%
df
# Out:
#       Date     Month  Year  Holidays_Count      Days   PM2.5    PM10     NO2  \
# 0        1   January  2021               0    Friday  408.80  442.42  160.61
# 1        2   January  2021               0  Saturday  404.04  561.95   52.85
# 2        3   January  2021               1    Sunday  225.07  239.04  170.95
# 3        4   January  2021               0    Monday   89.55  132.08  153.98
# 4        5   January  2021               0   Tuseday   54.06   55.54  122.66
# ...    ...       ...   ...             ...       ...     ...     ...     ...
# 1456    27  December  2024               0    Friday   58.43  249.17   41.69
# 1457    28  December  2024               0  Saturday   33.83  150.77   33.31
# 1458    29  December  2024               1    Sunday   31.21  139.75   27.01
# 1459    30  December  2024               0    Monday   38.01  152.83   29.12
# 1460    31  December  2024               0   Tuseday   80.42  318.96   40.37
#
#         SO2    CO  Ozone  AQI
# 0     12.95  2.77  43.19  462
# 1      5.18  2.60  16.43  482
# 2     10.93  1.40  44.29  263
# 3     10.42  1.01  49.19  207
# 4      9.70  0.64  48.88  149
# ...     ...   ...    ...  ...
# 1456  65.89  0.99  36.25  263
# 1457  66.14  0.79  35.19  113
# 1458  65.94  0.57  35.88  142
# 1459  65.16  0.55  38.38  116
# 1460  64.98  0.84  39.93  209
#
# [1461 rows x 12 columns]

# %% [markdown]
# Which month in each year recorded the highest average PM2.5 levels?

# %%
y21 = df[df["Year"] == 2021]
y22 = df[df["Year"] == 2022]
y23 = df[df["Year"] == 2023]
y24 = df[df["Year"] == 2024]

# %%
g21 = y21.groupby("Month")["PM2.5"].mean()
g21 = g21.sort_values(ascending=False)[:1]
g22 = y22.groupby("Month")["PM2.5"].mean()
g22 = g22.sort_values(ascending=False)[:1]
g23 = y23.groupby("Month")["PM2.5"].mean()
g23 = g23.sort_values(ascending=False)[:1]
g24 = y24.groupby("Month")["PM2.5"].mean()
g24 = g24.sort_values(ascending=False)[:1]

# %%
print("Year 2021")
print(g21)
print()
print("Year 2022")
print(g22)
print()
print("Year 2023")
print(g23)
print()
print("Year 2024")
print(g24)
print()
# Out:
# Year 2021
# Month
# November    243.365
# Name: PM2.5, dtype: float64
#
# Year 2022
# Month
# April    161.924667
# Name: PM2.5, dtype: float64
#
# Year 2023
# Month
# January    158.01
# Name: PM2.5, dtype: float64
#
# Year 2024
# Month
# November    138.728667
# Name: PM2.5, dtype: float64

# %% [markdown]
# Is there a correlation between PM10 and AQI?

# %%
cor = df[["PM10","AQI"]]
cor
# Out:
#         PM10  AQI
# 0     442.42  462
# 1     561.95  482
# 2     239.04  263
# 3     132.08  207
# 4      55.54  149
# ...      ...  ...
# 1456  249.17  263
# 1457  150.77  113
# 1458  139.75  142
# 1459  152.83  116
# 1460  318.96  209
#
# [1461 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
correlation = cor["AQI"].corr(cor["PM10"])
print(f"Correlation between PM10 and AQI,(Correlation*100)%)")
plt.scatter(cor["PM10"],cor["AQI"])
plt.title("AQI vs PM10")
plt.xlabel("PM10")
plt.ylabel("AQI")
plt.show()
# Out:
# Correlation between PM10 and AQI,(Correlation*100)%)

# %% [markdown]
# How does AQI vary on holidays compared to non-holidays?

# %%
holiday = df[df["Holidays_Count"] == 1]
non_holiday = df[df["Holidays_Count"] == 0]

# %%
avg1 = holiday["AQI"].mean()
avg2 = non_holiday["AQI"].mean()

# %%
print("Holiday AQI Average")
print(avg1)
print()
print("non-Holiday AQI Average")
print(avg2)
# Out:
# Holiday AQI Average
# 202.31046931407943
#
# non-Holiday AQI Average
# 202.1875

# %%
li = [avg1 , avg2]
label = ["Holidays","Non-Holidays1"]

# %%
plt.pie(li , labels = label , autopct = "%.2f" , radius = 0.7 ,shadow = True)
plt.show()

# %% [markdown]
# What is the trend of NO2 levels over the years?

# %%
df
# Out:
#       Date     Month  Year  Holidays_Count      Days   PM2.5    PM10     NO2  \
# 0        1   January  2021               0    Friday  408.80  442.42  160.61
# 1        2   January  2021               0  Saturday  404.04  561.95   52.85
# 2        3   January  2021               1    Sunday  225.07  239.04  170.95
# 3        4   January  2021               0    Monday   89.55  132.08  153.98
# 4        5   January  2021               0   Tuseday   54.06   55.54  122.66
# ...    ...       ...   ...             ...       ...     ...     ...     ...
# 1456    27  December  2024               0    Friday   58.43  249.17   41.69
# 1457    28  December  2024               0  Saturday   33.83  150.77   33.31
# 1458    29  December  2024               1    Sunday   31.21  139.75   27.01
# 1459    30  December  2024               0    Monday   38.01  152.83   29.12
# 1460    31  December  2024               0   Tuseday   80.42  318.96   40.37
#
#         SO2    CO  Ozone  AQI
# 0     12.95  2.77  43.19  462
# 1      5.18  2.60  16.43  482
# 2     10.93  1.40  44.29  263
# 3     10.42  1.01  49.19  207
# 4      9.70  0.64  48.88  149
# ...     ...   ...    ...  ...
# 1456  65.89  0.99  36.25  263
# 1457  66.14  0.79  35.19  113
# 1458  65.94  0.57  35.88  142
# 1459  65.16  0.55  38.38  116
# 1460  64.98  0.84  39.93  209
#
# [1461 rows x 12 columns]

# %%
df["Year"]=df["Year"].astype(str)

# %%
group = df.groupby("Year")["NO2"].mean()
group.plot(kind = "line")
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# Which pollutant shows the strongest correlation with AQI

# %%
cor = df[["PM2.5","PM10","NO2","SO2","CO","Ozone","AQI"]]
cor
# Out:
#        PM2.5    PM10     NO2    SO2    CO  Ozone  AQI
# 0     408.80  442.42  160.61  12.95  2.77  43.19  462
# 1     404.04  561.95   52.85   5.18  2.60  16.43  482
# 2     225.07  239.04  170.95  10.93  1.40  44.29  263
# 3      89.55  132.08  153.98  10.42  1.01  49.19  207
# 4      54.06   55.54  122.66   9.70  0.64  48.88  149
# ...      ...     ...     ...    ...   ...    ...  ...
# 1456   58.43  249.17   41.69  65.89  0.99  36.25  263
# 1457   33.83  150.77   33.31  66.14  0.79  35.19  113
# 1458   31.21  139.75   27.01  65.94  0.57  35.88  142
# 1459   38.01  152.83   29.12  65.16  0.55  38.38  116
# 1460   80.42  318.96   40.37  64.98  0.84  39.93  209
#
# [1461 rows x 7 columns]

# %%
correlation = cor["AQI"],corr(cor["PM10"])
print(f"Correlation B/W PM10 & AQI is {correlation*100}%")

correlation = cor["AQI"],corr(cor["PM2.5"])
print(f"Correlation B/W PM2.5 & AQI is {correlation*100}%")

correlation = cor["AQI"],corr(cor["NO2"])
print(f"Correlation B/W NO2 & AQI is {correlation*100}%")

correlation = cor["AQI"],corr(cor["SO2"])
print(f"Correlation B/W SO2 & AQI is {correlation*100}%")

correlation = cor["AQI"],corr(cor["Ozone"])
print(f"Correlation B/W Ozone & AQI is {correlation*100}%")
print()

fig , ax = plt.subplots(3,2)

ax[0,0].scatter(cor["PM10"] , cor["AQI"] , marker = ".")
ax[0,0].set_title("AQI VS PM10")
ax[0,0].set_xlabel("PM10")
ax[0,0].set_ylabel("AQI")

ax[0,1].scatter(cor["PM2.5"] , cor["AQI"] , marker = ".")
ax[0,1].set_title("AQI VS PM2.5")
ax[0,1].set_xlabel("PM2.5")
ax[0,1].set_ylabel("AQI")

ax[1,1].scatter(cor["NO2"] , cor["AQI"] , marker = ".")
ax[1,1].set_title("AQI VS NO2")
ax[1,1].set_xlabel("NO2")
ax[1,1].set_ylabel("AQI")

ax[2,0].scatter(cor["SO2"] , cor["AQI"] , marker = ".")
ax[2,0].set_title("AQI VS PM10")
ax[2,0].set_xlabel("SO2")
ax[2,0].set_ylabel("AQI")

ax[2,2].scatter(cor["Ozone"] , cor["AQI"] , marker = ".")
ax[2,2].set_title("AQI VS PM10")
ax[2,2].set_xlabel("Ozone")
ax[2,2].set_ylabel("AQI")

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 correlation = cor["AQI"],corr(cor["PM10"])
#       2 print(f"Correlation B/W PM10 & AQI is {correlation*100}%")
#       4 correlation = cor["AQI"],corr(cor["PM2.5"])
#
# NameError: name 'corr' is not defined
